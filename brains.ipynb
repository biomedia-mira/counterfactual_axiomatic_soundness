# %%
from pathlib import Path
from datasets.brains import brains

brains(Path('data'), True, confound_strength=20.)
# Out:
# /vol/biomedic/users/mm6818/projects/grand_canyon/datasets/utils.py:104: UserWarning: Distribution does not have full support in:
# sequence == 1, age == 0
#   warnings.warn(f'Distribution does not have full support in:\n{message}')
# /vol/biomedic/users/mm6818/projects/grand_canyon/datasets/utils.py:125: RuntimeWarning: invalid value encountered in true_divide
#   weights = interventional_dist / histogram
# /vol/biomedic/users/mm6818/projects/grand_canyon/datasets/utils.py:125: RuntimeWarning: divide by zero encountered in true_divide
#   weights = interventional_dist / histogram
# (): max_num_repeat=1; new_dataset_len:8899
# ('sequence',): max_num_repeat=1086; new_dataset_len:23703
# ('age',): max_num_repeat=1086; new_dataset_len:23703
# ('sequence', 'age'): max_num_repeat=1086; new_dataset_len:23703
# ('confounded_confound_strength_20.0',
# ...
